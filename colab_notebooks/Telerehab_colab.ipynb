# %%
# %cd /content/
# !git clone https://github.com/claraguoguo/TeleRehab.git
# %cd /content/TeleRehab/
! git checkout colab
! ls
# Out:
# /content
# Cloning into 'TeleRehab'...
# remote: Enumerating objects: 644, done.
# remote: Counting objects: 100% (644/644), done.
# remote: Compressing objects: 100% (428/428), done.
# remote: Total 644 (delta 422), reused 424 (delta 205), pack-reused 0
# Receiving objects: 100% (644/644), 125.10 KiB | 5.96 MiB/s, done.
# Resolving deltas: 100% (422/422), done.
# /content/TeleRehab
# Already on 'colab'
# Your branch is up to date with 'origin/colab'.
# colab_config.cfg  load_data.py	plot_train.py  train_NN_sklearn.py
# config.cfg	  model.py	README.md      train.py
# dataset.py	  models	train_LSTM.py  train_weighted_loss.py
# input		  opts.py	train_NN.py    util.py

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! git pull
! git branch
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
! pip install scikit-video
# Out:
# ...
#      |████████████████████████████████| 2.3MB 5.7MB/s
# ...

# %%
# %cd /content/TeleRehab/

# Your code with pytorch using GPU
# ! python train.py --config colab_config.cfg --model_name cnn
# ! python train.py --config colab_config.cfg --model_name c3d

! python train.py --config colab_config.cfg --model_name c3d
! python train.py --config colab_config.cfg --model_name cnn
! python train.py --config colab_config.cfg --model_name resnet
# Out:
# Streaming output truncated to the last 5000 lines.
# outputs: tensor([[32.0264]], device='cuda:0'),
# labels: tensor([29.], device='cuda:0', dtype=torch.float64)
# Training loss = 9.159198760986328
# Epoch: 28, Batch: 17,
# outputs: tensor([[34.3889]], device='cuda:0'),
# labels: tensor([39.8631], device='cuda:0', dtype=torch.float64)
# Training loss = 29.966419219970703
# Epoch: 28, Batch: 18,
# outputs: tensor([[35.7859]], device='cuda:0'),
# labels: tensor([31.], device='cuda:0', dtype=torch.float64)
# Training loss = 22.905059814453125
# Epoch: 28, Batch: 19,
# outputs: tensor([[35.8951]], device='cuda:0'),
# labels: tensor([33.2391], device='cuda:0', dtype=torch.float64)
# Training loss = 7.054347038269043
# Epoch: 28, Batch: 20,
# outputs: tensor([[33.7095]], device='cuda:0'),
# labels: tensor([25.], device='cuda:0', dtype=torch.float64)
# Training loss = 75.85498046875
# Epoch: 28, Batch: 21,
# outputs: tensor([[33.6946]], device='cuda:0'),
# ...

# %%
# %cd /content/TeleRehab/
# !git reset --hard
# !git pull
# Out:
# /content/TeleRehab
# HEAD is now at 579eb63 Fixed the type error with max_frame_num (must be int) and fixed error with loading skeletal_video_path for specified exercise_type
# Already up to date.
